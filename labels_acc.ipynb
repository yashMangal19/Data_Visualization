# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
persons = [ 'P' + f"{num:02}" for num in range(1,18)]
persons
# Out:
# ['P01',
#  'P02',
#  'P03',
#  'P04',
#  'P05',
#  'P06',
#  'P07',
#  'P08',
#  'P09',
#  'P10',
#  'P11',
#  'P12',
#  'P13',
#  'P14',
#  'P15',
#  'P16',
#  'P17']

# %%
from datetime import datetime

def convert_to_datetime(unix):
    # Assuming you have a 13-digit Unix timestamp
    timestamp_milliseconds = unix # Example timestamp

    # Convert to a datetime object
    datetime_object = datetime.utcfromtimestamp(timestamp_milliseconds / 1000.0)

    return datetime_object

print(convert_to_datetime(1638550730008))
# Out:
# 2021-12-03 16:58:50.008000

# %%
from datetime import datetime, timezone

def convert_to_unix_gmt(time):
    # Input datetime string
    datetime_string = time

    # Parse the datetime string into a datetime object
    datetime_object = datetime.strptime(datetime_string, "%Y-%m-%d %H:%M:%S")

    # Convert the datetime object to a Unix timestamp (13-digit, in milliseconds)
    unix_timestamp = int(datetime_object.replace(tzinfo=timezone.utc).timestamp() * 1000)

    return unix_timestamp

print(convert_to_unix_gmt("2021-11-29 10:34:54"))
# Out:
# 1638182094000

# %%
df =  pd.read_csv(f"unrefined/P01/P01-imu-right.csv")
# Out:
# /var/folders/61/x37yxxt16cn46ybk_2c3j5bw0000gn/T/ipykernel_21486/2525577315.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =  pd.read_csv(f"unrefined/P01/P01-imu-right.csv")

# %%
df
# Out:
#                   timestamp     ax     ay    az    gx    gy   gz
# 0       2021-12-03 16:53:50  16120    753  2697  1045 -1119 -437
# 1                     17325  16057    755  2718  1013 -1148 -259
# 2                     17335  15987    769  2740   958 -1098 -171
# 3                     17345  15996    753  2737   910  -983 -133
# 4                     17354  16035    750  2756   880  -883 -104
# ...                     ...    ...    ...   ...   ...   ...  ...
# 222015              2140357   3292  15187  4645   -75    67   60
# 222016              2140367   3326  15226  4632   -82    70   38
# 222017              2140376   3363  15260  4629   -85    97   30
# 222018              2140386   3384  15290  4667   -77   134   36
# 222019              2140395   3376  15291  4703   -67   149   58
#
# [222020 rows x 7 columns]

# %%
# As the first row in the dataset has timing 16:53:50 and the study information has start time of 16:58:50
# And as during our visualization also we saw there were around 30000 (5 mins in milliseconds) of incosistancies.
df.drop(index=df.index[:30312], axis=0, inplace=True)
df
# Out:
#        timestamp    ax     ay    az  gx   gy  gz
# 30312     300008  2294  16028  1162 -24   41 -58
# 30313     300018  2304  16050  1176 -14   28 -53
# 30314     300027  2301  16051  1176  -7   12 -40
# 30315     300037  2284  16054  1200   1   -8 -36
# 30316     300047  2270  16048  1191  10  -26 -28
# ...          ...   ...    ...   ...  ..  ...  ..
# 222015   2140357  3292  15187  4645 -75   67  60
# 222016   2140367  3326  15226  4632 -82   70  38
# 222017   2140376  3363  15260  4629 -85   97  30
# 222018   2140386  3384  15290  4667 -77  134  36
# 222019   2140395  3376  15291  4703 -67  149  58
#
# [191708 rows x 7 columns]

# %%
df["timestamp"] = df["timestamp"].astype("int64")

# %%
# Adding 1638530630000 to the timestamp column in the dataset to make it exact unix time.
# As it is relative to "2021-12-03 16:53:50" right now.

df.iloc[:,0] = df.iloc[:,0] + 1638550430000

# %%
df
# Out:
#             timestamp    ax     ay    az  gx   gy  gz
# 30312   1638550730008  2294  16028  1162 -24   41 -58
# 30313   1638550730018  2304  16050  1176 -14   28 -53
# 30314   1638550730027  2301  16051  1176  -7   12 -40
# 30315   1638550730037  2284  16054  1200   1   -8 -36
# 30316   1638550730047  2270  16048  1191  10  -26 -28
# ...               ...   ...    ...   ...  ..  ...  ..
# 222015  1638552570357  3292  15187  4645 -75   67  60
# 222016  1638552570367  3326  15226  4632 -82   70  38
# 222017  1638552570376  3363  15260  4629 -85   97  30
# 222018  1638552570386  3384  15290  4667 -77  134  36
# 222019  1638552570395  3376  15291  4703 -67  149  58
#
# [191708 rows x 7 columns]

# %%
df.to_csv("P01-imu-right.csv",index=False)

# %%
df6 =  pd.read_csv(f"unrefined/P06/P06-imu-right.csv")
# Out:
# /var/folders/61/x37yxxt16cn46ybk_2c3j5bw0000gn/T/ipykernel_21486/3778666030.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df6 =  pd.read_csv(f"unrefined/P06/P06-imu-right.csv")

# %%
df6
# Out:
#                   timestamp    ax     ay     az   gx   gy   gz
# 0       2021-11-29 10:34:54 -3242  10330 -11986 -153  -93  100
# 1                      7169 -3251  10376 -12009 -142 -145  123
# 2                      7178 -3315  10365 -12069 -133 -177  145
# 3                      7188 -3346  10346 -12083  -82 -197  177
# 4                      7197 -3322  10361 -12066  -37 -218  190
# ...                     ...   ...    ...    ...  ...  ...  ...
# 245963              2368404 -1972  15565  -3337 -191  305 -496
# 245964              2368413 -1995  15556  -3288 -193  324 -502
# 245965              2368423 -2030  15562  -3303 -214  313 -500
# 245966              2368433 -2044  15561  -3337 -225  311 -475
# 245967              2368442 -2108  15535  -3331 -237  322 -457
#
# [245968 rows x 7 columns]

# %%
# As the first row in the dataset has timing 10:34:54 and the study information has start time of 10:37:54
# And as during our visualization also we saw there were around 18000 (3 mins in milliseconds) of incosistancies.
df6.drop(index=df6.index[:18006], axis=0, inplace=True)
df6
# Out:
#        timestamp    ax     ay     az   gx   gy   gz
# 18006     180017 -1035  11853 -10881    6 -579  185
# 18007     180026 -1052  11853 -10842    7 -602  199
# 18008     180036 -1036  11862 -10827    3 -629  212
# 18009     180045 -1055  11845 -10836   -1 -654  230
# 18010     180055 -1053  11840 -10819    2 -691  243
# ...          ...   ...    ...    ...  ...  ...  ...
# 245963   2368404 -1972  15565  -3337 -191  305 -496
# 245964   2368413 -1995  15556  -3288 -193  324 -502
# 245965   2368423 -2030  15562  -3303 -214  313 -500
# 245966   2368433 -2044  15561  -3337 -225  311 -475
# 8   2021-11-30 09:36:00  2021-11-30 09:41:20  2021-11-30 09:46:20
# 9   2021-11-30 11:50:20  2021-11-30 11:55:30  2021-11-30 12:01:00
# 10  2021-11-30 15:39:40  2021-11-30 15:45:00  2021-11-30 15:51:00
# 11  2021-12-03 11:23:10  2021-12-03 11:29:20  2021-12-03 11:34:30
# 12  2021-11-30 18:48:20  2021-11-30 18:53:20  2021-11-30 18:58:00
# 13  2021-12-01 11:05:00  2021-12-01 11:05:00  2021-12-01 11:05:00
# 14  2021-12-01 11:22:00  2021-12-01 11:29:00  2021-12-01 11:36:00
# 15  2021-12-01 19:01:00  2021-12-01 19:06:05  2021-12-01 19:20:30
# 16  2021-12-02 17:20:45  2021-12-02 17:26:30  2021-12-02 17:33:40
#
#     Cycle_Speed1  Cycle_Speed2  Run_Speed1  Run_Speed2  \
# 0             14            20         4.0         6.0
# 1             14            19         5.0         8.5
# 2             18            22         6.0         7.0
# 3             15            22         6.0         9.0
# 4             15            22         5.0         7.0
# 5             14            20         5.0         7.0
# 6             16            23         5.5         8.0
# 7              9            18         5.0         9.0
# 8             14            30         6.4         9.0
# 9             20            24         5.0         6.5
# 10            13            20         5.0         6.0
# 11            20            30         7.0        11.0
# 12            15            27         5.0         8.0
# 13            11            20         5.0         6.5
# 14            17            30         9.0        12.0
# 15            20            34         9.0        16.0
# 16            21            30         8.0         9.5
#
#                                              Comments  MET_Sit  MET_Stand  \
# 0                                                            1        1.2
# 1   Muse headband data lost due to connectivity is...        1        1.2
# 2                       Second part V02 data got losT        1        1.2
# 3                               Interruption at 18:41        1        1.2
# 4                                                            1        1.2
# 5                               VO2 data was lost (?)        1        1.2
# 6                       Low quality HR during running        1        1.2
# 7                                                            1        1.2
# 8                                                            1        1.2
# 9              Sleepiness level 2 if 4 is very sleepy        1        1.2
# 10  Problem with mask not fitting properly - Sleep...        1        1.2
# 11   at 11:15 VO2 and earbuds stopped and I restarted        1        1.2
# 12                                                           1        1.2
# 13  HR measured by Wahoo and Zephyr is similar dur...        1        1.2
# 14  Stopped the treadmill at 11:30 - Earbud fell o...        1        1.2
# 15                            VO2 Stopped at 19:07:50        1        1.2
# 16                                   Stopped at 17:32        1        1.2
#
#     MET_Cycle1  MET_Cycle2  MET_Run1  MET_Run2
# 0           10          16       4.5      10.0
# 1           10          12       8.0      14.0
# 2           12          16      10.0      11.5
# 3           10          16      10.0      15.0
# 4           10          16       8.0      11.5
# 5           10          16       8.0      11.5
# 6           12          16       9.0      13.5
# 7            4          12       8.0      15.0
# 8           10          16      11.0      15.0
# 9           16          16       8.0      11.0
# 10           8          16       8.0      10.0
# 11          16          16      11.5      18.0
# 12          10          16       8.0      13.5
# 13           6          16       8.0      11.0
# 14          12          16      15.0      20.0
# 15          16          16      15.0      20.0
# 16          16          16      13.5      15.5
